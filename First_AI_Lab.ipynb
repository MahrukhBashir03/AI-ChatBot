# %% [markdown]
# <a href="https://colab.research.google.com/github/MahrukhBashir03/AI-ChatBot/blob/main/First_AI_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10
b = 20
c = 30
print(a+b+c)
# Out:
# 60

# %%
a = 10
b = 20
c = 30
print("a=", a, "b=",b, "a+b=", a+b)
# Out:
# a= 10 b= 20 a+b= 30

# %%
a = 5
print(type(a))
b = 4.5
print(type(b))
c = (3+2j)
print(type(c))
print(type(True))
print(type("I am learning python"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>
# <class 'str'>

# %%
print("Enter a number of seconds:")
time = int(input(" "))
print("Here is the time in hours, minutes, and seconds:")
Hours = print(time // 3600)
minutes = print((time // 60) % 60)
seconds = print(time % 60)
# Out:
# Enter a number of seconds:
#  11370
# Here is the time in hours, minutes, and seconds:
# 3
# 9
# 30

# %%
future_value = float(input())
print("Enter the desired future value:", future_value)
rate = input()
print("Enter the annual interest rate:",rate)
years = input()
print("Enter the number of years the money will grow:", years)
present_value = future_value / (1.0 + rate)**years
print("You will need to deposit this amount:", present_value)
# Out:
# 10000
# Enter the desired future value: 10000
# 0.05
# Enter the annual interest rate: 0.05
# 10
# Enter the number of years the money will grow: 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2458b9fe2370> in <cell line: 0>()
#       5 years = input()
#       6 print("Enter the number of years the money will grow:", years)
# ----> 7 present_value = future_value / (1.0 + rate)**years
#       8 print("You will need to deposit this amount:", present_value)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
print("Hello \t World")
# Out:
# Hello 	 World

# %%
print("Hello World \n")
print("Hello")
# Out:
# Hello World
#
# Hello

# %%
number = int(input())
if(number % 2 == 0):
   print("Number is even")
else:
    print("Number is odd")
# Out:
# 6
# Number is even

# %%
print("Get the number of hours worked")
hours_worked= int(input())
print("Enter the hourly pay rate")
hourly_pay = int(input())
overtime = hours_worked-40
pay = hourly_pay * hours_worked
overtime_pay = overtime * hourly_pay * 1.5
gross_pay = pay + overtime_pay
print("The gross pay is", gross_pay)
# Out:
# Get the number of hours worked
# 45
# Enter the hourly pay rate
# 45
# The gross pay is 2362.5

# %%
marks = int(input())
if(marks > 50):
  print('Pass')
else:
  print("Fail")
# Out:
# 67
# Pass
